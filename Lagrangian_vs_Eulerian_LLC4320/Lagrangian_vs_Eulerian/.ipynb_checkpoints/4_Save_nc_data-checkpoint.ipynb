# %% [markdown]
# # llc4320 drifters spectra: Lagrangian vs Eulerian

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
import dask.dataframe as dd
from xhistogram.xarray import histogram
import xskillscore as xs
# %matplotlib inline
from matplotlib import pyplot as plt
from cmocean import cm
import matplotlib.colors as colors
from matplotlib import gridspec

import mitequinox.utils as ut
import mitequinox.parcels as pa
import mitequinox.drifters as dr
# Out:
# INFO: Compiled ParcelsRandom ==> /dev/shm/pbs.6439668.datarmor0/parcels-502027/libparcels_random_5aa8a884-1b59-44f2-bd20-4c377abeab57.so

# %%
if True:
    from dask.distributed import Client, LocalCluster
    from dask_jobqueue import PBSCluster
    #cluster = PBSCluster()
    cluster = PBSCluster(cores=28, processes=14) # necessary?
    w = cluster.scale(jobs=1)
    client = Client(cluster)
    client
else:
    from dask.distributed import Client, LocalCluster
    #
    cluster = LocalCluster()
    client = Client(cluster)
    client

# %%
client
# Out:
# <Client: 'tcp://10.148.0.111:58591' processes=14 threads=28, memory=111.72 GiB>

# %% [markdown]
# ______________
# ## lat*lon maps

# %%
E = '/home/datawork-lops-osi/equinox/mit4320/diags'
E_Eulerian = xr.open_zarr(os.path.join(ut.root_data_dir,'diags/SSUV_T60_lat_lon_bands_from_2Dbin_spectra.zarr'))
E_Eulerian = (E_Eulerian.rename({'E_SSUV':'E_Eulerian'}))
E_Eulerian
# Out:
# <xarray.Dataset>
# Dimensions:         (frequency_band: 15, lat_bins: 119, lon_bins: 359)
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5
# Data variables:
#     E_Eulerian      (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 45, 30), meta=np.ndarray>

# %%
root_dir = '/home/datawork-lops-osi/equinox/mit4320/parcels/'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(root_dir+run_name, parquets=['trajectory'])
E_lagrangian = p.load_diagnostic('spectra_uv_T60_mean0_lat_lon_bands.zarr')
E_lagrangian = E_lagrangian.rename({'E':'E_Lagrangian0'})
E_lagrangian0 = E_lagrangian.E_Lagrangian0
E_lagrangian0
# Out:
# <xarray.DataArray 'E_Lagrangian0' (frequency_band: 15, lon_bins: 359, lat_bins: 119)>
# dask.array<open_dataset-6419eef61746138f7a56ffae4aeafae2E, shape=(15, 359, 119), dtype=float64, chunksize=(1, 359, 119), chunktype=numpy.ndarray>
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5

# %%
root_dir = '/home/datawork-lops-osi/equinox/mit4320/parcels/'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(root_dir+run_name, parquets=['trajectory'])
E_lagrangian = p.load_diagnostic('spectra_uv_T60_mean1_lat_lon_bands.zarr')
E_lagrangian = E_lagrangian.rename({'E':'E_Lagrangian1'})
E_lagrangian1 = E_lagrangian.E_Lagrangian1
E_lagrangian1
# Out:
# <xarray.DataArray 'E_Lagrangian1' (frequency_band: 15, lon_bins: 359, lat_bins: 119)>
# dask.array<open_dataset-b42b7a5db3bdecfa9ea3fa94ba8aef72E, shape=(15, 359, 119), dtype=float64, chunksize=(1, 359, 119), chunktype=numpy.ndarray>
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5

# %%
root_dir = '/home/datawork-lops-osi/equinox/mit4320/parcels/'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(root_dir+run_name, parquets=['trajectory'])
E_lagrangian = p.load_diagnostic('spectra_uv_T60_mean2_lat_lon_bands.zarr')
E_lagrangian = E_lagrangian.rename({'E':'E_Lagrangian2'})
E_lagrangian2 = E_lagrangian.E_Lagrangian2
E_lagrangian2
# Out:
# <xarray.DataArray 'E_Lagrangian2' (frequency_band: 15, lon_bins: 359, lat_bins: 119)>
# dask.array<open_dataset-91e995c7fc8152e5abb5df15c72c56b5E, shape=(15, 359, 119), dtype=float64, chunksize=(1, 359, 119), chunktype=numpy.ndarray>
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5

# %%
# 2D binned Depth
V = ["SSUV"]
T = ["T60"]

sub = 1
dl = 1.
lon = np.arange(-180.,180., dl)
lat = np.arange(-60., 60., dl)
    
for v in V:
    for t in T:
        
        # read data
        ds = xr.open_zarr(os.path.join(ut.root_data_dir,'diags/spectra_%s_%s.zarr'%(v,t)))
        ds = ds.isel(i=slice(0,None,sub),j=slice(0,None,sub))
        #ds = ds.where(ds.Depth>1000, drop=False)
        #ds = ds.load()
        
        # lat, lon binning
        ds['lon'] = 0*ds.face+ds.XC
        ds['lat'] = 0*ds.face+ds.YC
        N = histogram(
                      ds.lon.load(), ds.lat.load(), 
                      bins=[lon, lat], 
                      dim=['i', 'j', 'face'], 
                      block_size=None
                     )

        E = histogram(
                      ds.lon.load(), ds.lat.load(),
                      bins=[lon, lat], 
                      weights= ds.Depth.load(), 
                      dim=['i', 'j', 'face'], 
                      block_size=None
                     )
        
        # get binned results
        Depth_bin = (E/N).rename('E_depth').rename({'lon_bin': 'lon_bins','lat_bin': 'lat_bins'})

# %%
ds_E = xr.merge([E_Eulerian,E_lagrangian0,E_lagrangian1,E_lagrangian2,Depth_bin])
ds_E
# Out:
# <xarray.Dataset>
# Dimensions:         (frequency_band: 15, lat_bins: 119, lon_bins: 359)
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5
# Data variables:
#     E_Eulerian      (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 45, 30), meta=np.ndarray>
#     E_Lagrangian0   (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 359, 119), meta=np.ndarray>
#     E_Lagrangian1   (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 359, 119), meta=np.ndarray>
#     E_Lagrangian2   (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 359, 119), meta=np.ndarray>
#     E_depth         (lon_bins, lat_bins) float64 4.548e+03 ... 3.74e+03

# %% [markdown]
# ______________
# ## Save as .nc

# %%
ds_E.load()
# Out:
# <xarray.Dataset>
# Dimensions:         (frequency_band: 15, lat_bins: 119, lon_bins: 359)
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5
# Data variables:
#     E_Eulerian      (frequency_band, lon_bins, lat_bins) float64 0.1136 ... 0...
#     E_Lagrangian0   (frequency_band, lon_bins, lat_bins) float64 0.09624 ... ...
#     E_Lagrangian1   (frequency_band, lon_bins, lat_bins) float64 0.04549 ... ...
#     E_Lagrangian2   (frequency_band, lon_bins, lat_bins) float64 0.04797 ... ...
#     E_depth         (lon_bins, lat_bins) float64 4.548e+03 ... 3.74e+03

# %%
out_dir_zarr = '/home1/datawork/xyu/others/' # could change to datawork file

file_out = out_dir_zarr+'/KE_lat_lon_band_together.nc'
# %time ds_E.to_netcdf(file_out, mode='w')
# Out:
# CPU times: user 20 ms, sys: 12 ms, total: 32 ms
# Wall time: 192 ms

# %%
cluster.close()
