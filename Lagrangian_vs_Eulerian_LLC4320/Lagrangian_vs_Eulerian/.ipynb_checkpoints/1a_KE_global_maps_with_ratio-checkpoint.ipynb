# %% [markdown]
# # llc4320 drifters spectra: Lagrangian vs Eulerian

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
import dask.dataframe as dd
from xhistogram.xarray import histogram
import xskillscore as xs
# %matplotlib inline
from matplotlib import pyplot as plt
from cmocean import cm
import matplotlib.colors as colors
from matplotlib import gridspec

import mitequinox.utils as ut
import mitequinox.parcels as pa
import mitequinox.drifters as dr
# Out:
# INFO: Compiled ParcelsRandom ==> /dev/shm/pbs.6298564.datarmor0/parcels-502027/libparcels_random_a4162b7b-de15-4d8e-94b3-997498ff7a4e.so

# %%
if True:
    from dask.distributed import Client, LocalCluster
    from dask_jobqueue import PBSCluster
    #cluster = PBSCluster()
    cluster = PBSCluster(cores=28, processes=14) # necessary?
    w = cluster.scale(jobs=1)
    client = Client(cluster)
    client
else:
    from dask.distributed import Client, LocalCluster
    #
    cluster = LocalCluster()
    client = Client(cluster)
    client

# %%
client
# Out:
# <Client: 'tcp://10.148.0.242:40500' processes=14 threads=28, memory=111.72 GiB>

# %% [markdown]
# ______________
# ## lat*lon maps

# %%
E = '/home/datawork-lops-osi/equinox/mit4320/diags'
L = '/home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics'

# %%
E_Eulerian = xr.open_zarr(os.path.join(ut.root_data_dir,'diags/SSUV_T60_lat_lon_bands_from_2Dbin_spectra.zarr'))
E_Eulerian = (E_Eulerian.rename({'E_SSUV':'E_Eulerian'}))
E_Eulerian
# Out:
# <xarray.Dataset>
# Dimensions:         (frequency_band: 15, lat_bins: 119, lon_bins: 359)
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5
# Data variables:
#     E_Eulerian      (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 45, 30), meta=np.ndarray>

# %%
root_dir = '/home/datawork-lops-osi/equinox/mit4320/parcels/'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(root_dir+run_name, parquets=['trajectory'])
E_lagrangian = p.load_diagnostic('spectra_uv_T60_mean0_lat_lon_bands.zarr')
E_lagrangian = E_lagrangian.rename({'E':'E_Lagrangian'})
E_lagrangian = E_lagrangian.E_Lagrangian
E_lagrangian
# Out:
# <xarray.DataArray 'E_Lagrangian' (frequency_band: 15, lon_bins: 359, lat_bins: 119)>
# dask.array<open_dataset-6419eef61746138f7a56ffae4aeafae2E, shape=(15, 359, 119), dtype=float64, chunksize=(1, 359, 119), chunktype=numpy.ndarray>
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5

# %%
# 2D binned Depth
V = ["SSUV"]
T = ["T60"]

sub = 1
dl = 1.
lon = np.arange(-180.,180., dl)
lat = np.arange(-60., 60., dl)
    
for v in V:
    for t in T:
        
        # read data
        ds = xr.open_zarr(os.path.join(ut.root_data_dir,'diags/spectra_%s_%s.zarr'%(v,t)))
        ds = ds.isel(i=slice(0,None,sub),j=slice(0,None,sub))
        #ds = ds.where(ds.Depth>500, drop=False)
        #ds = ds.load()
        
        # lat, lon binning
        ds['lon'] = 0*ds.face+ds.XC
        ds['lat'] = 0*ds.face+ds.YC
        N = histogram(
                      ds.lon.load(), ds.lat.load(), 
                      bins=[lon, lat], 
                      dim=['i', 'j', 'face'], 
                      block_size=None
                     )

        E = histogram(
                      ds.lon.load(), ds.lat.load(),
                      bins=[lon, lat], 
                      weights= ds.Depth.load(), 
                      dim=['i', 'j', 'face'], 
                      block_size=None
                     )
        
        # get binned results
        Depth_bin = (E/N).rename('E_depth').rename({'lon_bin': 'lon_bins','lat_bin': 'lat_bins'})

# %%
ds_E = xr.merge([E_Eulerian,E_lagrangian,Depth_bin])
ds_E
# Out:
# <xarray.Dataset>
# Dimensions:         (frequency_band: 15, lat_bins: 119, lon_bins: 359)
# Coordinates:
#   * frequency_band  (frequency_band) object 'total' 'low' ... 'inertial_0dot4'
#   * lat_bins        (lat_bins) float64 -59.5 -58.5 -57.5 ... 56.5 57.5 58.5
#   * lon_bins        (lon_bins) float64 -179.5 -178.5 -177.5 ... 177.5 178.5
# Data variables:
#     E_Eulerian      (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 45, 30), meta=np.ndarray>
#     E_Lagrangian    (frequency_band, lon_bins, lat_bins) float64 dask.array<chunksize=(1, 359, 119), meta=np.ndarray>
#     E_depth         (lon_bins, lat_bins) float64 4.548e+03 ... 3.74e+03

# %% [markdown]
# # Figures

# %% [markdown]
# ## Low-freq

# %%
font_size = 24
band = 'total'
fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-2, vmax=1e0), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-2, vmax=1e0), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
font_size = 24
band = 'low'
fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-2, vmax=1e0), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-2, vmax=1e0), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# # High freq

# %%
font_size = 24
band = 'semidiurnal_0dot1'

fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
font_size = 24
band = 'semidiurnal_0dot4'

fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
font_size = 24
band = 'diurnal_0dot1'

fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
font_size = 24
band = 'supertidal'

fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.sel(frequency_band=band)/(ds_E.E_Lagrangian.sel(frequency_band=band)+ds_E.E_Eulerian.sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.sel(frequency_band=band)-ds_E.E_Eulerian.sel(frequency_band=band))/ds_E.E_Eulerian.sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
font_size = 24
band = 'inertial_0dot1'
lat_mask = 5

fig = plt.figure(figsize=(32,32))
gs = gridspec.GridSpec(4, 4, figure=fig) 

ax1 = fig.add_subplot(gs[0, 0:2])
cax=(ds_E.E_Lagrangian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax1, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax1.set_xlim(-180., 180.)
ax1.set_xticks([-180., -90., 0., 90., 180.])
ax1.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax1.set_ylim(-60., 60.)
ax1.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax1.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax1.tick_params(direction='out', length=10, width=1)
ax1.set_title('Lagrangian',fontsize=font_size)
ax1.tick_params(labelsize=font_size)
ax1.set_ylabel('',fontsize=font_size)
ax1.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax2 = fig.add_subplot(gs[0, 2:4])
cax=(ds_E.E_Eulerian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.matter, norm=colors.LogNorm(vmin=1e-3, vmax=1e-1), add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax2, extend='both', orientation='vertical')
cbar.ax.tick_params(labelsize=font_size)
cbar.set_label('(m$^2$ s$^{-2}$)', fontsize=font_size)
ax2.set_xlim(-180., 180.)
ax2.set_xticks([-180., -90., 0., 90., 180.])
ax2.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax2.set_ylim(-60., 60.)
ax2.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax2.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax2.tick_params(direction='out', length=10, width=1)
ax2.set_title('Eulerian',fontsize=font_size)
ax2.tick_params(labelsize=font_size)
ax2.set_ylabel('',fontsize=font_size)
ax2.set_xlabel('',fontsize=font_size)
#ax.set_anchor('W')

ax3 = fig.add_subplot(gs[1, 0:2])
cax = (ds_E.E_Lagrangian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)/(ds_E.E_Lagrangian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)+ds_E.E_Eulerian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band))).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax3, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax3.set_title('Lagrangian/(Lagrangian $+$ Eulerian)' ,fontsize=font_size)
ax3.set_xlim(-180., 180.)
ax3.set_xticks([-180., -90., 0., 90., 180.])
ax3.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax3.set_ylim(-60., 60.)
ax3.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax3.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax3.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax3.tick_params(labelsize=font_size)
ax3.set_ylabel('',fontsize=font_size)
ax3.set_xlabel('',fontsize=font_size)

ax4 = fig.add_subplot(gs[1, 2:4])
cax = ((ds_E.E_Lagrangian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)-ds_E.E_Eulerian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band))/ds_E.E_Eulerian.where(np.abs(ds_E.lat_bins)>lat_mask).sel(frequency_band=band)).plot(x='lon_bins', y='lat_bins', cmap=cm.balance, vmin=0, vmax=1, add_colorbar = False)
cbar = plt.colorbar(cax, ax=ax4, extend='both', orientation='vertical', ticks=[0, 0.25, 0.5, 0.75, 1])
cbar.ax.tick_params(labelsize=font_size)
ax4.set_title('(Lagrangian $-$ Eulerian)/Eulerian',fontsize=font_size)
ax4.set_xlim(-180., 180.)
ax4.set_xticks([-180., -90., 0., 90., 180.])
ax4.set_xticklabels(['$180\degree$W','$90\degree$W','$0\degree$','$90\degree$E','$180\degree$E'])
ax4.set_ylim(-60., 60.)
ax4.set_yticks([-60., -40., -20., 0., 20., 40., 60.])
ax4.set_yticklabels(['$60\degree$S','$40\degree$S','$20\degree$S','$0\degree$','$20\degree$N','$40\degree$N','$60\degree$N'])
ax4.tick_params(direction='out', length=10, width=1)
cbar.set_label('', fontsize=font_size)
ax4.tick_params(labelsize=font_size)
ax4.set_ylabel('',fontsize=font_size)
ax4.set_xlabel('',fontsize=font_size)
#plt.tight_layout()

#plt.savefig('/home1/datahome/xyu/equinox_working/Lagrangian_vs_Eulerian_LLC4320/Figures/Global_map_total_KE.png')
# Out:
# Text(0.5, 0, '')

# %%
cluster.close()
