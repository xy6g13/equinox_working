# %% [markdown]
# # llc4320 drifters spectra: Lagrangian

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
from cmocean import cm
import dask.dataframe as dd
from xhistogram.xarray import histogram

# %matplotlib inline
from matplotlib import pyplot as plt
import mitequinox.utils as ut
import mitequinox.parcels as pa
import mitequinox.drifters as dr
# Out:
# INFO: Compiled ParcelsRandom ==> /dev/shm/pbs.5867192.datarmor0/parcels-502027/libparcels_random_616d795d-3bd3-4a99-a4e6-7c8b6419059c.so

# %%
if True:
    from dask.distributed import Client, LocalCluster
    from dask_jobqueue import PBSCluster
    #cluster = PBSCluster()
    cluster = PBSCluster() # necessary?
    #w = cluster.scale(jobs=15)
    w = cluster.scale(jobs=3)
    # 3 needed for lagrangian lon/lat binning
    # 15 for eulerian binning
    client = Client(cluster)
    client
else:
    from dask.distributed import Client, LocalCluster
    #
    cluster = LocalCluster()
    client = Client(cluster)
    client

# %%
client
# Out:
# <Client: 'tcp://10.148.0.242:42222' processes=21 threads=21, memory=335.37 GiB>

# %% [markdown]
# ---
# # Lagrangian spectra
# ### last update: 2023.07.04

# %%
D = '/home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics'

# %%
# load Lagrangian data
root_dir = '/home/datawork-lops-osi/equinox/mit4320/parcels/'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(root_dir+run_name, parquets=['trajectory'])

# %% [markdown]
# ---
# ## 1. lat x lon binning (i.e. 2D spectra)
#
# ## This is done by AP

# %%
# load spectra
ds = p.load_diagnostic('spectra_uv_T60_mean0_lon_lat.zarr')
fig, ax = plt.subplots(figsize=(15,6))
ax = plt.subplot(111)
np.log10(ds.E.sel(frequency=2)).plot(x='lon_bins',cmap='viridis', vmin=-5, vmax=-1)

# %%
ds = p.load_diagnostic('spectra_uv_T60_mean0_lon_lat.zarr')
ds.E.sel(frequency=.2).isel(lat_bins=110).plot()

# %% [markdown]
# ## 2 Zonally averaged spectra (i.e.,1D, as a function of lat)
# ### method 1: from raw Lagrangian spectra

# %%
#root_dir = '/home1/datawork/aponte/parcels/'
root_dir = os.path.join(ut.root_data_dir, 'parcels')

#run_name = 'global_extra_T365j_dt1j_dij50'
run_name = 'global_T365j_dt1j_dij50'

p = pa.parcels_output(os.path.join(root_dir, run_name), 
                      parquets=['trajectory_mean'],
                     )
#df = p['trajectory']

# %%
v = 'uv'

suffix = '_T60_mean2'

# read raw spectra
spectra_name = 'spectra_raw_'+v+suffix
    
df = p.load_diagnostic(spectra_name)
#df = df.persist()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /dev/shm/pbs.5867192.datarmor0/ipykernel_43770/627848861.py in <module>
#       9 df = p.load_diagnostic(spectra_name)
#      10 #df = df.persist()
# ---> 11 df.head()
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#    1047             Whether to compute the result, default is True.
#    1048         """
# -> 1049         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1050
#    1051     def _head(self, n, npartitions, compute, safe):
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1080
#    1081         if compute:
# -> 1082             result = result.compute()
#    1083         return result
#    1084
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     282         dask.base.compute
#     283         """
# --> 284         (result,) = compute(self, traverse=False, **kwargs)
#     285         return result
#     286
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     564         postcomputes.append(x.__dask_postcompute__())
#     565
# --> 566     results = schedule(dsk, keys, **kwargs)
#     567     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     568
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2664                     should_rejoin = False
#    2665             try:
# -> 2666                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2667             finally:
#    2668                 for f in futures.values():
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1973             else:
#    1974                 local_worker = None
# -> 1975             return self.sync(
#    1976                 self._gather,
#    1977                 futures,
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     841             return future
#     842         else:
# --> 843             return sync(
#     844                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     845             )
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     351     if error[0]:
#     352         typ, exc, tb = error[0]
# --> 353         raise exc.with_traceback(tb)
#     354     else:
#     355         return result[0]
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/utils.py in f()
#     334             if callback_timeout is not None:
#     335                 future = asyncio.wait_for(future, callback_timeout)
# --> 336             result[0] = yield future
#     337         except Exception as exc:
#     338             error[0] = sys.exc_info()
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1838                             exc = CancelledError(key)
#    1839                         else:
# -> 1840                             raise exception.with_traceback(traceback)
#    1841                         raise exc
#    1842                     if errors == "skip":
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/dataframe/io/parquet/core.py in read_parquet_part()
#     379
#     380     if isinstance(part, list):
# --> 381         dfs = [
#     382             func(fs, rg, columns.copy(), index, **toolz.merge(kwargs, kw))
#     383             for (rg, kw) in part
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/dataframe/io/parquet/core.py in <listcomp>()
#     380     if isinstance(part, list):
#     381         dfs = [
# --> 382             func(fs, rg, columns.copy(), index, **toolz.merge(kwargs, kw))
#     383             for (rg, kw) in part
#     384         ]
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/dask/dataframe/io/parquet/fastparquet.py in read_partition()
#     786             for row_group in row_groups:
#     787                 dfs.append(
# --> 788                     parquet_file.read_row_group_file(
#     789                         row_group,
#     790                         columns,
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/api.py in read_row_group_file()
#     208                     rg.num_rows, columns, categories, index)
#     209             ret = True
# --> 210         core.read_row_group_file(
#     211                 fn, rg, columns, categories, self.schema, self.cats,
#     212                 open=self.open, selfmade=self.selfmade, index=index,
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/core.py in read_row_group_file()
#     301                         scheme='hive', partition_meta=None):
#     302     with open(fn, mode='rb') as f:
# --> 303         return read_row_group(f, rg, columns, categories, schema_helper, cats,
#     304                               selfmade=selfmade, index=index, assign=assign,
#     305                               scheme=scheme, partition_meta=partition_meta)
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/core.py in read_row_group()
#     352     if assign is None:
#     353         raise RuntimeError('Going with pre-allocation!')
# --> 354     read_row_group_arrays(file, rg, columns, categories, schema_helper,
#     355                           cats, selfmade, assign=assign)
#     356
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/core.py in read_row_group_arrays()
#     327             continue
#     328
# --> 329         read_col(column, schema_helper, file, use_cat=name+'-catdef' in out,
#     330                  selfmade=selfmade, assign=out[name],
#     331                  catdef=out.get(name+'-catdef', None))
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/core.py in read_col()
#     243         else:
#     244             skip_nulls = False
# --> 245         defi, rep, val = read_data_page(infile, schema_helper, ph, cmd,
#     246                                         skip_nulls, selfmade=selfmade)
#     247         if rep is not None and assign.dtype.kind != 'O':  # pragma: no cover
#
# ~/.miniconda3/envs/equinox/lib/python3.8/site-packages/fastparquet/core.py in read_data_page()
#     138             values = np.zeros(nval, dtype=np.int8)
#     139     else:
# --> 140         raise NotImplementedError('Encoding %s' % daph.encoding)
#     141     return definition_levels, repetition_levels, values[:nval]
#     142
#
# NotImplementedError: Encoding 8

# %%
V = ["mean0","mean1","mean2"]

for v in V:

    # read raw spectra
    df = p.load_diagnostic('spectra_raw_uv_T60_%s'%(v))
    #df.head()

    # add bathymetry to dataframe
    def interp_bathy(df):
        bathy = ut.load_bathy(15)
        ds = df[['lon','lat']].to_xarray()
        ds_interpolated = bathy.interp(lon=ds['lon'], lat=ds['lat'])
        df_interpolated = ds_interpolated.to_dataframe()[bathy.name]
        return df.assign(**{bathy.name: df_interpolated})

    df = df.map_partitions(interp_bathy)

    # filter out depth ranges
    df = df[df['h']>500]
    #df.head()

    # bin geographically
    dl = 1.
    lat_bins = np.arange(-60, 60, dl)

    df['lat_cut'] = df['lat'].map_partitions(pd.cut, bins=lat_bins)

    E = df.groupby(['lat_cut']).mean().compute()

    #Converting pandas dataframe in xarray dataset:
    ds = (pd.melt(E.set_index(E.index.map(lambda v: v.mid))
                  .drop(columns=['time','lon','lat', 'h'])
                  .reset_index(), 
                  id_vars=['lat_cut',], 
                  var_name='frequency')
                  .rename(columns={'lat_cut': 'lat_bins', 
                                   'value': 'E'},
                         )
         ).to_xarray().set_index(index=['lat_bins','frequency']).unstack()
    ds['frequency'] = ds['frequency'].astype(float)
    ds = ds.sortby('frequency')

    p.store_diagnostic('spectra_uv_T60_%s_lat'%(v), ds, overwrite=True)

# %%
V = ["mean0","mean1","mean2"]

for v in V:

    # read raw spectra
    df = p.load_diagnostic('spectra_raw_uv_T60_%s'%(v))
    #df.head()

    # add bathymetry to dataframe
    def interp_bathy(df):
        bathy = ut.load_bathy(15)
        ds = df[['lon','lat']].to_xarray()
        ds_interpolated = bathy.interp(lon=ds['lon'], lat=ds['lat'])
        df_interpolated = ds_interpolated.to_dataframe()[bathy.name]
        return df.assign(**{bathy.name: df_interpolated})

    df = df.map_partitions(interp_bathy)

    # filter out depth ranges
    df = df[df['h']>500]
    #df.head()

    # bin geographically
    dl = 1.
    lat_bins = np.arange(-60, 60, dl)

    df['lat_cut'] = df['lat'].map_partitions(pd.cut, bins=lat_bins)

    E = df.groupby(['lat_cut']).mean().compute()

    #Converting pandas dataframe in xarray dataset:
    ds = (pd.melt(E.set_index(E.index.map(lambda v: v.mid))
                  .drop(columns=['time','lon','lat', 'h'])
                  .reset_index(), 
                  id_vars=['lat_cut',], 
                  var_name='frequency')
                  .rename(columns={'lat_cut': 'lat_bins', 
                                   'value': 'E'},
                         )
         ).to_xarray().set_index(index=['lat_bins','frequency']).unstack()
    ds['frequency'] = ds['frequency'].astype(float)
    ds = ds.sortby('frequency')

    p.store_diagnostic('spectra_uv_T60_%s_lat'%(v), ds, overwrite=True)

# %%
df = p.load_diagnostic('spectra_raw_uv_T60_mean0')

# %%
df
# Out:
# Dask DataFrame Structure:
#                     lon      lat       id      0.0 0.016666666666666666 0.03333333333333333     0.05 0.06666666666666667 0.08333333333333333      0.1 0.11666666666666667 0.13333333333333333     0.15 0.16666666666666666 0.18333333333333332      0.2 0.21666666666666667 0.23333333333333334     0.25 0.26666666666666666 0.2833333333333333      0.3 0.31666666666666665 0.3333333333333333     0.35 0.36666666666666664 0.3833333333333333      0.4 0.4166666666666667 0.43333333333333335     0.45 0.4666666666666667 0.48333333333333334      0.5 0.5166666666666666 0.5333333333333333     0.55 0.5666666666666667 0.5833333333333334      0.6 0.6166666666666667 0.6333333333333333     0.65 0.6666666666666666 0.6833333333333333      0.7 0.7166666666666667 0.7333333333333333     0.75 0.7666666666666666 0.7833333333333333      0.8 0.8166666666666667 0.8333333333333334     0.85 0.8666666666666667 0.8833333333333333      0.9 0.9166666666666666 0.9333333333333333     0.95 0.9666666666666667 0.9833333333333333      1.0 1.0166666666666666 1.0333333333333332     1.05 1.0666666666666667 1.0833333333333333      1.1 1.1166666666666667 1.1333333333333333     1.15 1.1666666666666667 1.1833333333333333      1.2 1.2166666666666666 1.2333333333333334     1.25 1.2666666666666666 1.2833333333333332      1.3 1.3166666666666667 1.3333333333333333     1.35 1.3666666666666667 1.3833333333333333      1.4 1.4166666666666667 1.4333333333333333     1.45 1.4666666666666666 1.4833333333333334      1.5 1.5166666666666666 1.5333333333333332     1.55 1.5666666666666667 1.5833333333333333      1.6 1.6166666666666667 1.6333333333333333     1.65 1.6666666666666667 1.6833333333333333      1.7 1.7166666666666666 1.7333333333333334     1.75 1.7666666666666666 1.7833333333333332      1.8 1.8166666666666667 1.8333333333333333 1.8499999999999999 1.8666666666666667 1.8833333333333333      1.9 1.9166666666666667 1.9333333333333333     1.95 1.9666666666666666 1.9833333333333334      2.0 2.0166666666666666 2.033333333333333     2.05 2.0666666666666664 2.0833333333333335      2.1 2.1166666666666667 2.1333333333333333     2.15 2.1666666666666665 2.183333333333333      2.2 2.216666666666667 2.2333333333333334     2.25 2.2666666666666666 2.283333333333333      2.3 2.3166666666666664 2.3333333333333335     2.35 2.3666666666666667 2.3833333333333333      2.4 2.4166666666666665 2.433333333333333     2.45 2.466666666666667 2.4833333333333334      2.5 2.5166666666666666 2.533333333333333     2.55 2.5666666666666664 2.5833333333333335      2.6 2.6166666666666667 2.6333333333333333     2.65 2.6666666666666665 2.683333333333333      2.7 2.716666666666667 2.7333333333333334     2.75 2.7666666666666666 2.783333333333333      2.8 2.8166666666666664 2.8333333333333335     2.85 2.8666666666666667 2.8833333333333333      2.9 2.9166666666666665 2.933333333333333     2.95 2.966666666666667 2.9833333333333334      3.0 3.0166666666666666 3.033333333333333     3.05 3.0666666666666664 3.0833333333333335      3.1 3.1166666666666667 3.1333333333333333     3.15 3.1666666666666665 3.183333333333333      3.2 3.216666666666667 3.2333333333333334     3.25 3.2666666666666666 3.283333333333333      3.3 3.3166666666666664 3.3333333333333335     3.35 3.3666666666666667 3.3833333333333333      3.4 3.4166666666666665 3.433333333333333 3.4499999999999997 3.466666666666667 3.4833333333333334      3.5 3.5166666666666666 3.533333333333333     3.55 3.5666666666666664 3.5833333333333335      3.6 3.6166666666666667 3.6333333333333333     3.65 3.6666666666666665 3.683333333333333 3.6999999999999997 3.716666666666667 3.7333333333333334     3.75 3.7666666666666666 3.783333333333333      3.8 3.8166666666666664 3.8333333333333335     3.85 3.8666666666666667 3.8833333333333333      3.9 3.9166666666666665 3.933333333333333 3.9499999999999997 3.966666666666667 3.9833333333333334      4.0 4.016666666666667 4.033333333333333     4.05 4.066666666666666 4.083333333333333      4.1 4.116666666666666 4.133333333333333     4.15 4.166666666666667 4.18 ...
# npartitions=88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
#                 float64  float64  float64  float64              float64             float64  float64             float64             float64  float64             float64             float64  float64             float64             float64  float64             float64             float64  float64             float64            float64  float64             float64            float64  float64             float64            float64  float64            float64             float64  float64            float64             float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64            float64            float64            float64            float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64  float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64            float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64            float64           float64            float64  float64            float64           float64  float64            float64            float64  float64            float64            float64  float64            float64           float64            float64           float64            float64  float64           float64           float64  float64           float64           float64  float64           float64           float64  float64           float64      ...
#                     ...      ...      ...      ...                  ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                ...      ...                 ...                ...      ...                 ...                ...      ...                ...                 ...      ...                ...                 ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...                ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...               ...               ...      ...               ...               ...      ...               ...               ...      ...               ...      ...
# ...                 ...      ...      ...      ...                  ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                ...      ...                 ...                ...      ...                 ...                ...      ...                ...                 ...      ...                ...                 ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...                ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...               ...               ...      ...               ...               ...      ...               ...               ...      ...               ...      ...
#                     ...      ...      ...      ...                  ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                ...      ...                 ...                ...      ...                 ...                ...      ...                ...                 ...      ...                ...                 ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...                ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...               ...               ...      ...               ...               ...      ...               ...               ...      ...               ...      ...
#                     ...      ...      ...      ...                  ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                 ...      ...                 ...                ...      ...                 ...                ...      ...                 ...                ...      ...                ...                 ...      ...                ...                 ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...                ...                ...                ...                ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...      ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...                ...               ...      ...                ...                ...      ...                ...                ...      ...                ...               ...                ...               ...                ...      ...               ...               ...      ...               ...               ...      ...               ...               ...      ...               ...      ...
# Dask Name: read-parquet, 88 tasks

# %%
# no detrending
ds = p.load_diagnostic('spectra_uv_T60_mean0_lat.zarr')

# spectra_raw_uv_mean1_lat_xyu
fig, ax = plt.subplots(figsize=(15,6))
ax = plt.subplot(111)
np.log10(ds.E).plot(cmap='viridis', vmin=-5, vmax=-1)

# %% [markdown]
# ### method 2: from 2D binned Lagrangian spectra (i.e. from section 1)

# %%
V = ["mean0", "mean1", "mean2"]

for v in V:

    ds = p.load_diagnostic('spectra_uv_T60_%s_lon_lat.zarr'%(v))
    E = ds.mean('lon_bins')    
    p.store_diagnostic('spectra_uv_T60_%s_lat_from_2Dbinned_spectra'%(v), E, overwrite=True)
    print('<%s - allready processed>'%(v))
# Out:
# spectra_uv_T60_mean0_lat_from_2Dbinned_spectra diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean0_lat_from_2Dbinned_spectra.zarr
# <mean0 - allready processed>
# spectra_uv_T60_mean1_lat_from_2Dbinned_spectra diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean1_lat_from_2Dbinned_spectra.zarr
# <mean1 - allready processed>
# spectra_uv_T60_mean2_lat_from_2Dbinned_spectra diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean2_lat_from_2Dbinned_spectra.zarr
# <mean2 - allready processed>

# %%
# load
ds = p.load_diagnostic('spectra_uv_T60_mean0_lat_from_2Dbinned_spectra.zarr')

fig, ax = plt.subplots(figsize=(15,6))
ax = plt.subplot(111)
np.log10(ds.E).plot(cmap='viridis', vmin=-5, vmax=-1)

# %% [markdown]
# _____________
# # Lagrangian KE levels
#
# ## 3. lon x lat for band-integrated KE

# %%
V = ["mean0","mean1","mean2"]

for v in V:
    
    ds = p.load_diagnostic('spectra_uv_T60_%s_lon_lat.zarr'%(v))

    f_llc = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(ds.lat_bins))
    f_cpd_llc = f_llc*86400/2./np.pi

    bands = {'total': (0., 12), 'low': (0., .5), 
             'diurnal_0dot1': (0.9, 1.1), 'diurnal_0dot2': (0.8, 1.2), 'diurnal_0dot3': (0.7, 1.3), 'diurnal_0dot4': (0.6, 1.4),
             'semidiurnal_0dot1': (1.9, 2.1), 'semidiurnal_0dot2': (1.8, 2.2), 'semidiurnal_0dot3': (1.7, 2.3), 'semidiurnal_0dot4': (1.6, 2.4),
             'inertial_0dot1':(f_cpd_llc.values.min(),f_cpd_llc.values.max()),'inertial_0dot2':(f_cpd_llc.values.min(),f_cpd_llc.values.max()),
             'inertial_0dot3':(f_cpd_llc.values.min(),f_cpd_llc.values.max()),'inertial_0dot4':(f_cpd_llc.values.min(),f_cpd_llc.values.max())
            }
    
    domega = float(ds.frequency[1]- ds.frequency[0])

    Eb = {}
    for b, bounds in bands.items():
        #print('Frequency band {}, frequency bounds: {}-{} cpd'.format(b, bounds[0], bounds[1]))

        if b == "inertial_0dot1":
            _E = ds.E.where((np.abs(ds.frequency + f_cpd_llc)<=0.1), 
                        drop=False,
                       )
        elif b == "inertial_0dot2":
            _E = ds.E.where((np.abs(ds.frequency + f_cpd_llc)<=0.2), 
                        drop=False,
                       )
        elif b == "inertial_0dot3":
            _E = ds.E.where((np.abs(ds.frequency + f_cpd_llc)<=0.3), 
                        drop=False,
                       )
        elif b == "inertial_0dot4":
            _E = ds.E.where((np.abs(ds.frequency + f_cpd_llc)<=0.4), 
                        drop=False,
                       )            
            
        else:
            _E = ds.E.where((np.abs(ds.frequency)>=bounds[0]) & (np.abs(ds.frequency)<=bounds[1]), 
                            drop=False,
                           )

        E = domega * _E.sum('frequency')    
        Eb[b] = E.persist()

    # converts to single dataset and store:
    E = xr.concat(list(Eb.values()), 
                  dim=pd.Index(list(Eb.keys()),name='frequency_band'),
                 )
    
    E = E.where(E>0)
    # store diagnostic
    p.store_diagnostic('spectra_uv_T60_%s_lat_lon_bands'%(v), E.to_dataset(), overwrite=True)
# Out:
# spectra_uv_T60_mean0_lat_lon_bands diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean0_lat_lon_bands.zarr
# spectra_uv_T60_mean1_lat_lon_bands diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean1_lat_lon_bands.zarr
# spectra_uv_T60_mean2_lat_lon_bands diagnostics stored in /home/datawork-lops-osi/equinox/mit4320/parcels/global_T365j_dt1j_dij50/diagnostics/spectra_uv_T60_mean2_lat_lon_bands.zarr

# %%
ds = p.load_diagnostic('spectra_uv_T60_mean0_lat_lon_bands.zarr')
fig, ax = plt.subplots(figsize=(15,8))
ax = plt.subplot(1,1,1)
np.log10(ds.E).sel(frequency_band='low').plot(x='lon_bins',y='lat_bins',vmin=-3,vmax=0)

# %%
ds = p.load_diagnostic('spectra_uv_T60_mean0_lat_lon_bands.zarr')
fig, ax = plt.subplots(figsize=(15,8))
ax = plt.subplot(1,1,1)
np.log10(ds.E).sel(frequency_band='low').plot(x='lon_bins',y='lat_bins',vmin=-3,vmax=0)

# %%
ds.E.sel(frequency_band='low').isel(lat_bins=110).plot()

# %% [markdown]
# ## Close cluster

# %%
cluster.close()
