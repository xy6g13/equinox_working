# %% [markdown]
# # load data and do elementary calculations and plots

# %% [markdown]
# ---

# %%
import os
import numpy as np
import dask
import xarray as xr
from dask import compute, delayed
from matplotlib import pyplot as plt
# %matplotlib inline

from mitequinox.utils import *
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
dmethod = 1
#
if dmethod == 1:
    from dask.distributed import Client
    scheduler = os.getenv('DATAWORK')+'/dask/scheduler.json'
    client = Client(scheduler_file=scheduler)
elif dmethod == 2:
    from dask_jobqueue import PBSCluster
    # folder where data is spilled when RAM is filled up
    local_dir = os.getenv('TMPDIR')
    #
    cluster = PBSCluster(queue='mpi_1', local_directory=local_dir, interface='ib0', walltime='24:00:00',
                         threads=14, processes=2, memory='50GB', resource_spec='select=1:ncpus=28:mem=100g', 
                         death_timeout=100)
    w = cluster.start_workers(40)
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/distributed/utils.py:128: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [Errno 101] Network is unreachable
#   % (host, default, e), RuntimeWarning)

# %%
# if dmethod = 2, you need to wait for workers to spin up
if dmethod == 2:
    cluster.scheduler

# %%
# get dask handles and check dask server status
if dmethod == 2:
    from dask.distributed import Client
    client = Client(cluster)

# %%
client
# Out:
# <Client: scheduler='tcp://10.148.0.184:8786' processes=7 cores=98>

# %%
data_dir = '/home/datawork-lops-osi/data/mit4320/Eta/'
grid_dir = '/home/datawork-lops-osi/data/mit4320/grid/'

iters, time = get_iters_time('Eta', data_dir, delta_t=25.)

#ds = get_compressed_data('Eta', data_dir, grid_dir, iters=iters, time=time, client=None)
ds = get_compressed_data('Eta', data_dir, grid_dir, iters=iters, time=time, client=client)
ds = ds.chunk({'face': 1})
print(ds)
print('\n data size: %.1f GB' %(ds['Eta'].nbytes / 1e9))
print('\n data size (1 face): %.1f GB' %(ds['Eta'].isel(face=1).nbytes / 1e9))
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/xmitgcm/mds_store.py:721: UserWarning: Couldn't find available_diagnostics.log in . Using default version.
#   "in %s. Using default version." % data_dir)
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/xmitgcm/utils.py:314: UserWarning: Not sure what to do with rlev = L
#   warnings.warn("Not sure what to do with rlev = " + rlev)
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/xmitgcm/mds_store.py:235: FutureWarning: iteration over an xarray.Dataset will change in xarray v0.11 to only include data variables, not coordinates. Iterate over the Dataset.variables property instead to preserve existing behavior in a forwards compatible manner.
#   for vname in ds:
# <xarray.Dataset>
# Dimensions:  (face: 13, i: 4320, i_g: 4320, j: 4320, j_g: 4320, k: 90, k_l: 90, k_p1: 91, k_u: 90, time: 4690)
# Coordinates:
# ...

# %%
# plot one figure to check lon/lat treatment
import cartopy.crs as ccrs
from cmocean import cm

# %%
eta = ds['Eta'].isel(face=4, time=3200)

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
eta.plot(ax=ax, x='XC', y='YC', transform=ccrs.PlateCarree(),vmin=-3, vmax=3,  cmap='RdBu_r')

# %%
eta_1 = ds['Eta'].isel(face=4, i=1000, j=1000)
print(eta_1)
# Out:
# <xarray.DataArray 'Eta' (time: 4096)>
# dask.array<shape=(4096,), dtype=>f4, chunksize=(1,)>
# Coordinates:
#     i        int64 1000
#     j        int64 1000
#     face     int64 4
#     XC       >f4 dask.array<shape=(), chunksize=()>
#     YC       >f4 dask.array<shape=(), chunksize=()>
#     rA       >f4 dask.array<shape=(), chunksize=()>
#     Depth    >f4 dask.array<shape=(), chunksize=()>
#   * time     (time) float64 2.592e+05 2.628e+05 2.664e+05 2.7e+05 2.736e+05 ...

# %%
eta_1.plot()

# %%
eta_1.isel(time=slice(0,240)).plot()

# %%
(aa/86400).plot()

# %% [markdown]
# ---
#
# # make movie
#
#  Method 1: data is loaded locally by each worker

# %%
face = 4
vmin = -2.5
vmax = 2.5

#delete all figures beforehand
figdir = os.getenv('DATAWORK')+'/mit/figs/'
print(figdir)
print(face)
# Out:
# /home1/datawork/xyu/mit/figs/
# 4

# %%
time
# Out:
# <xarray.DataArray (iters: 4690)>
# array([  259200.,   262800.,   266400., ..., 17132400., 17136000., 17139600.])
# Coordinates:
#   * iters    (iters) int64 10368 10512 10656 10800 10944 11088 11232 11376 ...

# %%
iters
# Out:
# <xarray.DataArray (time: 4690)>
# array([ 10368,  10512,  10656, ..., 685296, 685440, 685584])
# Coordinates:
#   * time     (time) float64 2.592e+05 2.628e+05 2.664e+05 2.7e+05 2.736e+05 ...

# %%
def process(iters, time, i,  overwrite=True):
    
    ds = get_compressed_data('Eta', data_dir, grid_dir, iters=iters, time=time, client=None)
    ds = ds.chunk({'face': 1})
    
    eta = ds['Eta'].isel(face=face, time=i)

    #eta = eta.isel(i=slice(0,100),j=slice(0,100))
    #time = pd.to_datetime(str(eta['time'].values))
    
    time = eta['time'].values/86400.
    figname = figdir+'mit_eta_f%d_t%05d' %(face, i)+'.png'
    #
    if not os.path.isfile(figname) or overwrite:
        #
        title = 'eta %.2f' %time
        plot_scalar(eta, colorbar=False, title=title, savefig=figname, vmin=vmin, vmax=vmax, 
                    offline=True, coast_resolution='50m', figsize=(15,10), cmmap='balance')
        #
        m = float(eta.mean().values)
    else:
        m = -1.
    return m

# %%
I = range(len(ds['time']))
I = range(100)

#values = [delayed(process)(iters.isel(time=slice(i,i+1)), time.isel(iters=slice(i,i+1)), i) for i in range(0, 4096, 5)]

#values = [delayed(process)(iters.isel(time=slice(i,i+5)), time.isel(iters=i), i) for i in range(30)]
values = [delayed(process)(iters, time, i) for i in range(30)]

# %%
# %time results = compute(*values, get=client.get)
# Out:
# CPU times: user 284 ms, sys: 12 ms, total: 296 ms
# Wall time: 2min 51s

# %%
plt.plot(np.array(results))

# %% [markdown]
# ---
#
# # method 2 (fails):
#
# Try to use the dataset loaded initially
#
# This method fails with not various error messages.
# Workers may be running out of memory

# %%
face = 1
vmin = -2.
vmax = 2.

#delete all figures beforehand
figdir = os.getenv('DATAWORK')+'/mit/figs/'
print(figdir)

def process(eta, i, overwrite=True):
    
    # eta = eta.isel(i=slice(0,100),j=slice(0,100))

    #time = pd.to_datetime(str(eta['time'].values))
    time = eta['time'].values/86400.
    figname = figdir+'mit_eta_f%d_t%05d' %(face, i)+'.png'
    #
    if not os.path.isfile(figname) or overwrite:
        #
        title = 'eta %.2f' %time
        #plot_scalar(eta, colorbar=False, title=title, savefig=figname, vmin=vmin, vmax=vmax, 
        #         offline=True, coast_resolution='50m', figsize=(15,10))
        #
        m = float(eta.mean().values)
    else:
        m = -1.
    return m

I = range(len(ds['time']))
I = range(100)
values = [delayed(process)(ds['Eta'].isel(face=face, time=i), i) for i in I]
# Out:
# /home1/datawork/aponte/mit/figs/

# %%
# %time results = compute(*values, get=client.get)

# %% [markdown]
# ---
#
# # info, shutdown

# %%
client.restart()
# Out:
# <Client: scheduler='tcp://10.148.0.220:8786' processes=18 cores=252>

# %%
if dmethod == 2:
    client.close()
    cluster.stop_workers(cluster.jobs)
