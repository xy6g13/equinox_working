# %% [markdown]
# # Plots of spectral results

# %% [markdown]
# ---

# %%
import os
from glob import glob
import numpy as np
import dask
import xarray as xr
from matplotlib import pyplot as plt
# %matplotlib inline

import xrft

from mitequinox.utils import *

from cmocean import cm
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
dmethod = 1
#
if dmethod == 1:
    from dask.distributed import Client
    scheduler = os.getenv('DATAWORK')+'/dask/scheduler.json'
    client = Client(scheduler_file=scheduler)
elif dmethod == 2:
    from dask_jobqueue import PBSCluster
    # folder where data is spilled when RAM is filled up
    local_dir = os.getenv('TMPDIR')
    #
    cluster = PBSCluster(queue='mpi_1', local_directory=local_dir, interface='ib0', walltime='24:00:00',
                         threads=14, processes=2, memory='50GB', resource_spec='select=1:ncpus=28:mem=100g', 
                         death_timeout=100)
    w = cluster.start_workers(40)
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/distributed/utils.py:128: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [Errno 101] Network is unreachable
#   % (host, default, e), RuntimeWarning)

# %%
# you need to wait for workers to spin up
if dmethod == 2:
    cluster.scheduler

# %%
# get dask handles and check dask server status
if dmethod == 2:
    from dask.distributed import Client
    client = Client(cluster)

# %%
client
# Out:
# <Client: scheduler='tcp://10.148.0.4:8786' processes=20 cores=280>

# %% [markdown]
# ---
#
# # Eta

# %%
v = 'Eta'

# dir where spectra are stored
E_dir = '/home1/scratch/xyu/mit_spec/'

filenames = sorted(glob(E_dir+'E_Eta_zavg_f*.nc'))
print(E_dir)
# %time ds = xr.open_mfdataset(filenames, concat_dim='face', compat='equals')
# Out:
# /home1/scratch/xyu/mit_spec/
# CPU times: user 68 ms, sys: 4 ms, total: 72 ms
# Wall time: 80.2 ms

# %%
E = (ds.E*ds.A).sum(dim='face') / ds.A.sum(dim='face')
print(E)
# Out:
# <xarray.DataArray (lat: 120, freq_time: 1199)>
# dask.array<shape=(120, 1199), dtype=float64, chunksize=(120, 1199)>
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001388 -0.0001385 -0.0001383 ...

# %%
# Eta
plt.figure(figsize=(15,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.)
np.log10(E).plot.pcolormesh(ax=ax, vmin=-2., vmax=5., x='freq_cpd', y='lat', cmap = cm.deep)
ax.set_xticks(list(ax.get_xticks()) + [-4., -3., -2., -1., 1., 2., 3., 4.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-5., 5.)


# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
ax.plot(f*86400./2./np.pi,f.lat,'k--')
ax.plot(-f*86400./2./np.pi,f.lat,'k--')


#, x=E.freq_time*86400)

# %% [markdown]
# ______
#
# # SSU

# %%
v = 'SSU'

# dir where spectra are stored
E_dir = '/home1/scratch/xyu/mit_spec/'

filenames = sorted(glob(E_dir+'E_zavg_f*.nc'))
print(E_dir)
# %time ds = xr.open_mfdataset(filenames, concat_dim='face', compat='equals')
# Out:
# /home1/scratch/xyu/mit_spec/
# CPU times: user 52 ms, sys: 44 ms, total: 96 ms
# Wall time: 1.25 s

# %%
E = (ds.E*ds.A).sum(dim='face') / ds.A.sum(dim='face')
print(E)
# Out:
# <xarray.DataArray (lat: 120, freq_time: 1439)>
# dask.array<shape=(120, 1439), dtype=float64, chunksize=(120, 1439)>
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001388 -0.0001386 -0.0001384 ...

# %%
# SSU
plt.figure(figsize=(15,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.)
np.log10(E).plot.pcolormesh(ax=ax, vmin=-2., vmax=4., x='freq_cpd', y='lat', cmap = cm.deep)
ax.set_xticks(list(ax.get_xticks()) + [-4., -3., -2., -1., 1., 2., 3., 4.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-5., 5.)


# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
ax.plot(f*86400./2./np.pi,f.lat,'k--')
ax.plot(-f*86400./2./np.pi,f.lat,'k--')

# %% [markdown]
# # Rotary spectra (50 days)
#
# ______

# %%
# dir where spectra are stored
E_dir = '/home1/scratch/xyu/mit_spec/'

filenames = sorted(glob(E_dir+'E_rotary_zavg_f*.nc'))
# %time ds = xr.open_mfdataset(filenames, concat_dim='face', compat='equals')
print(ds)
print(filenames)
# Out:
# CPU times: user 24 ms, sys: 8 ms, total: 32 ms
# Wall time: 37.9 ms
# <xarray.Dataset>
# Dimensions:    (face: 5, freq_time: 1199, lat: 120)
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001388 -0.0001385 -0.0001383 ...
# Dimensions without coordinates: face
# Data variables:
#     E          (face, lat, freq_time) float64 dask.array<shape=(5, 120, 1199), chunksize=(1, 120, 1199)>
#     A          (face, lat) float64 dask.array<shape=(5, 120), chunksize=(1, 120)>
# ['/home1/scratch/xyu/mit_spec/E_rotary_zavg_f00.nc', '/home1/scratch/xyu/mit_spec/E_rotary_zavg_f01.nc', '/home1/scratch/xyu/mit_spec/E_rotary_zavg_f02.nc', '/home1/scratch/xyu/mit_spec/E_rotary_zavg_f03.nc', '/home1/scratch/xyu/mit_spec/E_rotary_zavg_f04.nc']

# %%
E = (ds.E*ds.A).sum(dim='face') / ds.A.sum(dim='face')
print(E)
# Out:
# <xarray.DataArray (lat: 120, freq_time: 1199)>
# dask.array<shape=(120, 1199), dtype=float64, chunksize=(120, 1199)>
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001388 -0.0001385 -0.0001383 ...

# %%
# Figure #
plt.figure(figsize=(16,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.) 
np.log10(E).plot.pcolormesh(ax=ax, vmin=-0., vmax=3., x='freq_cpd', y='lat', cmap = 'Spectral_r')

ax.set_xticks(list(ax.get_xticks()) + [-5., -4., -3., -2., -1., 1., 2., 3., 4., 5.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-6., 6.)

# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
#ax.plot(f*86400./2./np.pi,f.lat,'w--')
#ax.plot(-f*86400./2./np.pi,f.lat,'w--')

# %%
# Figure #
plt.figure(figsize=(16,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.) 
np.log10(E).plot.pcolormesh(ax=ax, vmin=-0., vmax=3., x='freq_cpd', y='lat', cmap = 'Spectral_r')

ax.set_xticks(list(ax.get_xticks()) + [-5., -4., -3., -2., -1., 1., 2., 3., 4., 5.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-3., 3.)

# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
ax.plot(f*86400./2./np.pi,f.lat,'k--')
ax.plot(-f*86400./2./np.pi,f.lat,'k--')

# %% [markdown]
# # Rotary spectra (20 days)

# %%
# dir where spectra are stored
E_dir = '/home1/scratch/xyu/mit_spec/'

filenames = sorted(glob(E_dir+'E_uv_zavg_f*.nc'))
# %time ds = xr.open_mfdataset(filenames, concat_dim='face', compat='equals')
print(ds)
# Out:
# CPU times: user 80 ms, sys: 8 ms, total: 88 ms
# Wall time: 785 ms
# <xarray.Dataset>
# Dimensions:    (face: 13, freq_time: 479, lat: 120)
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001386 -0.000138 -0.0001374 ...
# Dimensions without coordinates: face
# Data variables:
#     E          (face, lat, freq_time) float64 dask.array<shape=(13, 120, 479), chunksize=(1, 120, 479)>
#     A          (face, lat) float64 dask.array<shape=(13, 120), chunksize=(1, 120)>

# %%
E = (ds.E*ds.A).sum(dim='face') / ds.A.sum(dim='face')
print(E)
# Out:
# <xarray.DataArray (lat: 120, freq_time: 479)>
# dask.array<shape=(120, 479), dtype=float64, chunksize=(120, 479)>
# Coordinates:
#   * lat        (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 -54.5 -53.5 -52.5 ...
#   * freq_time  (freq_time) float64 -0.0001386 -0.000138 -0.0001374 ...

# %%
# Figure #
plt.figure(figsize=(16,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.) 
np.log10(E).plot.pcolormesh(ax=ax, vmin=-0., vmax=3., x='freq_cpd', y='lat', cmap = 'Spectral_r')

ax.set_xticks(list(ax.get_xticks()) + [-5., -4., -3., -2., -1., 1., 2., 3., 4., 5.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-6., 6.)

# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
#ax.plot(f*86400./2./np.pi,f.lat,'w--')
#ax.plot(-f*86400./2./np.pi,f.lat,'w--')

# %%
# Figure #
plt.figure(figsize=(16,10))
ax = plt.subplot(1,1,1)
E = E.assign_coords(freq_cpd=E.freq_time * 86400.) 
np.log10(E).plot.pcolormesh(ax=ax, vmin=-0., vmax=3., x='freq_cpd', y='lat', cmap = 'Spectral_r')

ax.set_xticks(list(ax.get_xticks()) + [-5., -4., -3., -2., -1., 1., 2., 3., 4., 5.])
ax.set_xlim(-12., 12.)
ax.set_xlim(-3., 3.)

# add coriolis frequency
f = 2.*2.*np.pi/86400. * np.sin(np.deg2rad(E.lat))
ax.plot(f*86400./2./np.pi,f.lat,'k--')
ax.plot(-f*86400./2./np.pi,f.lat,'k--')

# %%
client.restart()
# Out:
# <Client: scheduler='tcp://10.148.0.5:8786' processes=7 cores=98>
