# %%
import os
from glob import glob
import numpy as np
import dask
import xarray as xr
import cartopy.crs as ccrs
#import cmocean as cm
import seawater as sw
import gsw
import xgcm
from xgcm.autogenerate import generate_grid_ds

from matplotlib import pyplot as plt
# %matplotlib inline

from mitequinox.utils import *
from dask import compute, delayed
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/docrep/__init__.py:413: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   s = dedents(s)
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/docrep/__init__.py:342: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   s = dedents('\n' + '\n'.join(lines[first:]))

# %%
from dask_jobqueue import PBSCluster
local_dir = os.getenv('TMPDIR')
cluster = PBSCluster(local_directory=local_dir)
#print(cluster.job_script())
w = cluster.start_workers(15)
# Out:
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/distributed/utils.py:128: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [Errno 101] Network is unreachable
#   % (host, default, e), RuntimeWarning)
# /home1/datahome/xyu/.miniconda3/envs/equinox/lib/python3.6/site-packages/docrep/__init__.py:342: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   s = dedents('\n' + '\n'.join(lines[first:]))

# %%
# get dask handles and check dask server status
from dask.distributed import Client
client = Client(cluster)

# %%
client
# Out:
# <Client: scheduler='tcp://10.148.1.0:60711' processes=30 cores=120>

# %% [markdown]
# _________
# # 1. Read dataset

# %%
out_dir_zarr = '/home1/datawork/xyu/OSMOSIS_llc4320/data_rechunk/'

grid = xr.open_dataset(out_dir_zarr+'Grid.nc', decode_coords=True)
ds_U = xr.open_zarr(out_dir_zarr+'U_total_rechunk.zarr')
ds_V = xr.open_zarr(out_dir_zarr+'V_total_rechunk.zarr')
ds_W = xr.open_zarr(out_dir_zarr+'W_total_rechunk.zarr')
ds_D = xr.open_zarr(out_dir_zarr+'Pden_total_rechunk.zarr')
ds_T = xr.open_zarr(out_dir_zarr+'Theta_total_rechunk.zarr')

# buoyancy
ds_B = -9.81*(ds_D.Pden-25)/1025
ds_B = np.real(ds_B).rename('Buoy')
ds_B = ds_B.to_dataset()

ds = xr.merge([ds_U,ds_V,ds_W,ds_D,ds_B,ds_T,grid])
ds = generate_grid_ds(ds, {'Z':'depth'})
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:     (depth: 52, depth_left: 52, lat: 201, lat_g: 201, lon: 177, lon_g: 177, time: 9415)
# Coordinates:
#   * lat         (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon_g       (lon_g) float64 -18.04 -18.02 -18.0 -17.98 -17.96 -17.94 ...
#   * depth       (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 ...
#   * time        (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * lat_g       (lat_g) float64 47.4 47.41 47.42 47.44 47.45 47.46 47.48 ...
#   * lon         (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 ...
#     XC          (lat, lon) float32 ...
#     YC          (lat, lon) float32 ...
#     XG          (lat_g, lon_g) float32 ...
#     YG          (lat_g, lon_g) float32 ...
#     CS          (lat, lon) float32 ...
#     SN          (lat, lon) float32 ...
#     Depth       (lat, lon) float32 ...
#     dxC         (lat, lon_g) float32 ...
#     dyC         (lat_g, lon) float32 ...
# ...

# %%
gridx = xgcm.Grid(ds, coords={'X':{'center':'lon', 'left':'lon_g'},
                              'Y':{'center':'lat', 'left':'lat_g'},
                              'Z':{'center':'depth', 'left':'depth_left'}}, periodic=['X', 'Y'])
print(gridx)
# Out:
# <xgcm.Grid>
# X Axis (periodic):
#   * center   lon (177) --> left
#   * left     lon_g (177) --> center
# Y Axis (periodic):
#   * center   lat (201) --> left
#   * left     lat_g (201) --> center
# Z Axis (not periodic):
#   * center   depth (52) --> left
#   * left     depth_left (52) --> center

# %%
# Calculate vertical distances located on the cellboundary
ds.coords['dzc'] = gridx.diff(ds.depth, 'Z', boundary='extrapolate')
# Calculate vertical distances located on the cellcenter
ds.coords['dzt'] = gridx.diff(ds.depth_left, 'Z', boundary='extrapolate')
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (depth: 52, depth_left: 52, lat: 201, lat_g: 201, lon: 177, lon_g: 177, time: 9415)
# Coordinates:
#   * lat         (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon_g       (lon_g) float64 -18.04 -18.02 -18.0 -17.98 -17.96 -17.94 ...
#   * depth       (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 ...
#   * time        (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * lat_g       (lat_g) float64 47.4 47.41 47.42 47.44 47.45 47.46 47.48 ...
#   * lon         (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 ...
#     XC          (lat, lon) float32 ...
#     YC          (lat, lon) float32 ...
#     XG          (lat_g, lon_g) float32 ...
#     YG          (lat_g, lon_g) float32 ...
#     CS          (lat, lon) float32 ...
#     SN          (lat, lon) float32 ...
#     Depth       (lat, lon) float32 ...
#     dxC         (lat, lon_g) float32 ...
#     dyC         (lat_g, lon) float32 ...
# ...

# %% [markdown]
# # 2. Vertical gradient

# %% [markdown]
# ## 2.1 drho/dz

# %%
drho_dz_left = -1*gridx.diff(ds.Pden, 'Z', boundary='fill', fill_value=np.nan) / ds.dzc
drho_dz = gridx.interp(drho_dz_left,'Z', boundary='fill')
print(drho_dz)
# Out:
# <xarray.DataArray 'mul-0c7215fecb5c4e9080539c2d2b04c35b' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float64, chunksize=(9415, 1, 201, 177)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
fig = plt.figure(figsize=(24,10))
drho_dz.isel(lat=10,lon=10).plot(x='time', y='depth',vmin=-1e-3,vmax=1e-3, cmap='RdBu_r', yincrease=False)

# %% [markdown]
# ## 2.2 db/dz

# %%
db_dz_left = -1*gridx.diff(ds.Buoy, 'Z', boundary='fill', fill_value=np.nan) / ds.dzc
db_dz = gridx.interp(db_dz_left,'Z', boundary='fill')
print(db_dz)
# Out:
# <xarray.DataArray 'mul-9982c4abd0f876103e3d506985e8282a' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float64, chunksize=(9415, 1, 201, 177)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
fig = plt.figure(figsize=(24,10))
db_dz.isel(lat=10,lon=10).plot(x='time', y='depth',vmin=-0.0001,vmax=0.0001,cmap='RdBu_r', yincrease=False)

# %% [markdown]
# ## 2.3 dT/dz

# %%
dT_dz_left = -1*gridx.diff(ds.Theta, 'Z', boundary='fill', fill_value=np.nan) / ds.dzc
dT_dz = gridx.interp(dT_dz_left,'Z', boundary='fill')
print(dT_dz)
# Out:
# <xarray.DataArray 'mul-dcebd9f2edf4a7db862688b3527ac7f1' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float64, chunksize=(9415, 1, 201, 177)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
fig = plt.figure(figsize=(24,10))
dT_dz.isel(lat=10,lon=10).plot(x='time', y='depth',vmin=-0.05,vmax=0.05,cmap='RdBu_r', yincrease=False)

# %% [markdown]
# # 3. define perturbation (e.g., u', v')

# %%
w_mean = ds.W.mean(['lat','lon'])
b_mean = Buoy.mean(['lat','lon'])
u_mean = ds.U.mean(['lat','lon_g'])
v_mean = ds.V.mean(['lat_g','lon'])

# %%
w_prime = ds.W - w_mean
b_prime = Buoy - b_mean
u_prime = ds.U - u_mean
v_prime = ds.V - v_mean

# %%
u_prime_ij = gridx.interp(u_prime,'X')
u_prime_ij
# Out:
# <xarray.DataArray 'mul-5becb4a12687da27b6a9d5ecf5f3c756' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float32, chunksize=(9415, 1, 201, 176)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
v_prime_ij = gridx.interp(v_prime,'Y')
v_prime_ij
# Out:
# <xarray.DataArray 'mul-b4f5f4785f8713398835b096bcc8f399' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float32, chunksize=(9415, 1, 200, 177)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
#dU_dz = ( ds['U'].shift(depth=-1) - ds['U'].shift(depth=1) )/( ds['depth'].shift(depth=-1) - ds['depth'].shift(depth=1) )
#dU_dz_ij = gridx.interp(dU_dz,'X')
#dU_dz_ij

dU_dz_left = -1*gridx.diff(ds.U, 'Z', boundary='fill', fill_value=np.nan) / ds.dzc
dU_dz = gridx.interp(dU_dz_left,'Z', boundary='fill')
dU_dz_ij = gridx.interp(dU_dz,'X')
print(dU_dz_ij)
# Out:
# <xarray.DataArray 'mul-e042b0067db2058a17b2f9bdd8f21bd8' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float64, chunksize=(9415, 1, 201, 176)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %%
#dV_dz = ( ds['V'].shift(depth=-1) - ds['V'].shift(depth=1) )/( ds['depth'].shift(depth=-1) - ds['depth'].shift(depth=1) )
#dV_dz_ij = gridx.interp(dV_dz,'Y')
#dV_dz_ij

dV_dz_left = -1*gridx.diff(ds.V, 'Z', boundary='fill', fill_value=np.nan) / ds.dzc
dV_dz = gridx.interp(dV_dz_left,'Z', boundary='fill')
dV_dz_ij = gridx.interp(dV_dz,'Y')
print(dV_dz_ij)
# Out:
# <xarray.DataArray 'mul-76785a7da4f4648352b9987d616701f6' (time: 9415, depth: 52, lat: 201, lon: 177)>
# dask.array<shape=(9415, 52, 201, 177), dtype=float64, chunksize=(9415, 1, 200, 177)>
# Coordinates:
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * lat      (lat) float64 47.4 47.42 47.43 47.44 47.46 47.47 47.48 47.5 ...
#   * lon      (lon) float64 -18.03 -18.01 -17.99 -17.97 -17.95 -17.93 -17.91 ...

# %% [markdown]
# # 4. VSP

# %% [markdown]
# ## 4.1 Method 1

# %%
vsp_1 = -1*((w_prime * u_prime_ij).mean(['lat','lon']) * dU_dz_ij.mean(['lat','lon']) + (w_prime * v_prime_ij).mean(['lat','lon']) * dV_dz_ij.mean(['lat','lon']))
vsp_1.load()
vsp_1
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# array([[          nan, -3.480584e-09,  3.000753e-10, ...,  5.934344e-11,
#          8.841197e-12, -1.198412e-11],
#        [          nan, -2.572731e-09,  8.743798e-10, ...,  1.691448e-11,
#         -4.626540e-11, -4.614828e-11],
#        [          nan,  2.175551e-09,  3.102955e-09, ..., -9.517241e-11,
#         -2.026245e-10, -1.383153e-10],
#        ...,
#        [          nan,  6.064687e-10, -2.149900e-10, ..., -2.572301e-09,
#         -1.836207e-09, -7.990804e-10],
#        [          nan,  9.397402e-12, -1.352566e-09, ..., -2.062086e-09,
#         -1.299769e-09, -5.487724e-10],
#        [          nan, -5.178240e-10, -2.148912e-09, ..., -1.254758e-09,
#         -5.943510e-10, -2.137739e-10]])
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
# ...

# %%
fig = plt.figure(figsize=(15,15))
vsp_1.mean('time').plot(y='depth', yincrease=False)

# %%
fig = plt.figure(figsize=(24,10))
vsp_1.plot(x='time', y='depth',vmin=-5e-8,vmax=5e-8,cmap='RdBu_r', yincrease=False)

# %% [markdown]
# ## 4.2 Method 2

# %%
vsp_2 = -1*(w_prime * u_prime_ij * dU_dz_ij + w_prime * v_prime_ij * dV_dz_ij)
vsp_2_mean = vsp_2.mean(['lat','lon'])
vsp_2_mean.load()
vsp_2_mean
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# array([[          nan, -4.363008e-09,  1.343310e-11, ..., -4.937485e-09,
#         -3.717713e-09, -1.192233e-09],
#        [          nan, -3.255523e-09,  7.183907e-10, ..., -2.456803e-09,
#         -2.396780e-09, -8.156436e-10],
#        [          nan,  2.071382e-09,  3.219074e-09, ..., -1.820085e-09,
#         -2.918214e-09, -1.160719e-09],
#        ...,
#        [          nan, -1.944745e-09, -4.758891e-09, ..., -1.667899e-08,
#         -1.397240e-08, -4.984116e-09],
#        [          nan, -2.321748e-09, -5.542206e-09, ..., -2.941533e-09,
#         -5.066987e-09, -1.367572e-09],
#        [          nan, -2.401570e-09, -5.910557e-09, ...,  5.568225e-09,
#          4.845402e-09,  2.565616e-09]])
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
# ...

# %%
fig = plt.figure(figsize=(24,10))
vsp_2_mean.plot(x='time', y='depth',vmin=-5e-8,vmax=5e-8,cmap='RdBu_r', yincrease=False)

# %%
fig = plt.figure(figsize=(15,15))
vsp_2_mean.mean('time').plot(y='depth', yincrease=False)

# %% [markdown]
# ## 4.3 two method comparsion

# %%
fig = plt.figure(figsize=(15,15))
vsp_2_mean.mean('time').plot(y='depth', yincrease=False)
vsp_1.mean('time').plot(y='depth', yincrease=False)

# %% [markdown]
# # 5. w'b'

# %%
wb_prime = w_prime*b_prime
wb_prime_mean = wb_prime.mean(['lat','lon'])
wb_prime_mean
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# dask.array<shape=(9415, 52), dtype=float32, chunksize=(9415, 1)>
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#     dzt      (depth) float64 1.07 1.145 1.308 1.495 1.705 1.94 2.207 2.51 ...

# %%
wb_prime_mean.load()
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# array([[ 2.474635e-09,  2.640488e-09,  2.818504e-09, ...,  3.296893e-08,
#          2.560053e-08,  1.702176e-08],
#        [-2.907991e-09, -2.663564e-09, -2.391995e-09, ...,  1.186818e-08,
#          9.636948e-09,  9.009283e-09],
#        [-7.772551e-09, -7.404426e-09, -6.983015e-09, ..., -4.150024e-09,
#         -1.927034e-09,  4.031266e-09],
#        ...,
#        [ 1.250806e-09,  3.358193e-09,  5.534526e-09, ...,  5.959661e-08,
#          5.750657e-08,  5.834074e-08],
#        [ 4.536571e-10,  2.401019e-09,  4.646656e-09, ..., -4.857808e-08,
#         -3.294810e-08, -1.165507e-08],
#        [-9.984134e-11,  1.424576e-09,  3.215975e-09, ..., -1.492099e-07,
#         -1.134001e-07, -7.377513e-08]], dtype=float32)
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
# ...

# %%
fig = plt.figure(figsize=(24,10))
wb_prime_mean.isel(depth=slice(0,40)).plot(x='time', y='depth',vmin=-5e-7,vmax=5e-7,cmap='RdBu_r', yincrease=False)

# %%
wb_prime_smean = wb_prime_mean.mean('time')
fig, ax = plt.subplots(figsize=(16,10))

wb_prime_smean.plot(y='depth', yincrease=False)
ax.grid()
#vsp.mean('time').plot(y='depth')

# %% [markdown]
# # 6. Subdomain

# %%
vsp_2 = -1*(w_prime * u_prime_ij * dU_dz_ij + w_prime * v_prime_ij * dV_dz_ij)
vsp_2_mean = vsp_2.isel(lon=slice(80,100),lat=slice(90,110)).mean(['lat','lon'])
vsp_2_mean.load()
vsp_2_mean
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# array([[          nan,  3.185890e-08,  3.142421e-08, ...,  1.113233e-09,
#          1.258741e-09,  7.649135e-09],
#        [          nan,  3.148413e-08,  3.211063e-08, ...,  8.408226e-09,
#         -4.249627e-12,  3.910423e-09],
#        [          nan,  2.768742e-08,  2.978655e-08, ...,  1.121157e-08,
#          1.675674e-09,  5.612713e-09],
#        ...,
#        [          nan,  1.528605e-09,  7.317222e-09, ...,  3.710324e-09,
#          2.349553e-09,  3.070658e-09],
#        [          nan,  2.601923e-09,  1.435018e-08, ...,  5.874835e-08,
#          3.464690e-08,  5.279743e-09],
#        [          nan, -9.930788e-11,  1.630005e-08, ...,  1.259677e-07,
#          1.024832e-07,  3.323666e-08]])
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
# ...

# %%
wb_prime_mean_subdomain = wb_prime.isel(lon=slice(80,100),lat=slice(90,110)).mean(['lat','lon'])
wb_prime_mean_subdomain.persist()
# Out:
# <xarray.DataArray (time: 9415, depth: 52)>
# dask.array<shape=(9415, 52), dtype=float32, chunksize=(9415, 1)>
# Coordinates:
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 5.78 7.595 9.66 12.01 14.68 ...
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
#     dzt      (depth) float64 1.07 1.145 1.308 1.495 1.705 1.94 2.207 2.51 ...

# %%
fig = plt.figure(figsize=(24,10))
wb_prime_mean_subdomain.isel(depth=slice(0,40)).plot(x='time', y='depth',vmin=-5e-7,vmax=5e-7,cmap='RdBu_r', yincrease=False)

# %%
wb_prime_smean_subdomain = wb_prime_mean_subdomain.mean('time')

fig, ax = plt.subplots(figsize=(16,10))
wb_prime_smean_subdomain.plot(y='depth', yincrease=False)
ax.grid()
#vsp.mean('time').plot(y='depth')

# %%
cluster.scheduler.close()
# Out:
# <Future finished result=None>
